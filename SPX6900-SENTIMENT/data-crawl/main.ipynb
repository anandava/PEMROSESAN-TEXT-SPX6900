# %%
from dotenv import load_dotenv
import os

load_dotenv()
twitter_auth_token = os.getenv("TWITTER_AUTH_TOKEN")

# %%
# !mkdir -p node_env
# %cd node_env
# !npm init -y
# !npm install tweet-harvest@2.6.1 playwright
# !npx playwright install chromium
# Out:
# /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env
# Wrote to /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/package.json:
#
# {
#   "name": "node_env",
#   "version": "1.0.0",
#   "main": "index.js",
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1"
#   },
#   "keywords": [],
#   "author": "",
#   "license": "ISC",
#   "dependencies": {
#     "playwright": "^1.56.0",
#     "tweet-harvest": "^2.6.1"
#   },
#   "devDependencies": {},
#   "description": ""
# }
#
#
# m##################) ⠴ reify:fsevents: sill reify mark deleted [pleted in 1483ms
# up to date, audited 79 packages in 2s
#
# 8 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
# Crawl Data

filename = 'spx6900.csv'
search_keyword = 'spx6900 since:2025-08-01 until:2025-10-01 lang:en'
limit = 1500

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/spx6900.csv, renaming to ./tweets-data/spx6900.old.csv
#
# Filling in keywords: spx6900 since:2025-08-01 until:2025-10-01 lang:en
#
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/tweets-data/spx6900.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/tweets-data/spx6900.csv
# Total tweets saved: 37
#
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"/home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1973175314974122373  Tue Sep 30 23:57:09 +0000 2025               1
# 1     1973136808931209396  Tue Sep 30 23:54:57 +0000 2025               1
# 2     1973174474062307742  Tue Sep 30 23:53:49 +0000 2025              65
# 3     1973172315874832773  Tue Sep 30 23:45:14 +0000 2025              68
# 4     1973171958922813546  Tue Sep 30 23:43:49 +0000 2025               6
# ...                   ...                             ...             ...
# 1495  1972396421958795271  Sun Sep 28 23:42:58 +0000 2025               1
# 1496  1972069998962352244  Sun Sep 28 23:42:21 +0000 2025               4
# 1497  1972446752977596769  Sun Sep 28 23:42:06 +0000 2025              19
# 1498  1972445932450132259  Sun Sep 28 23:38:51 +0000 2025              22
# 1499  1972299005670605297  Sun Sep 28 23:37:50 +0000 2025               1
#
#                                               full_text               id_str  \
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah : {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah : 1500.
