# %%
from dotenv import load_dotenv
import os

load_dotenv()
twitter_auth_token = os.getenv("TWITTER_AUTH_TOKEN")

# %%
# !mkdir -p node_env
# %cd node_env
# !npm init -y
# !npm install tweet-harvest@2.6.1 playwright
# !npx playwright install chromium
# Out:
# /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env
# Wrote to /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/package.json:
#
# {
#   "name": "node_env",
#   "version": "1.0.0",
#   "description": "",
#   "main": "index.js",
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1"
#   },
#   "keywords": [],
#   "author": "",
#   "license": "ISC"
# }
#
#
# npm WARN deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# npm WARN deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supportedm
# npm WARN deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# m##################) ⠋ reify:lodash: timing reifyNode:node_modules/playwright-cm:n/fs
# added 78 packages, and audited 79 packages in 9s
#
# 8 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
# Crawl Data

filename = 'spx6900.csv'
search_keyword = 'spx6900 since:2025-08-01 until:2025-10-01 lang:en'
limit = 800

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Filling in keywords: spx6900 since:2025-08-01 until:2025-10-01 lang:en
#
#
# -- Scrolling... (1)Created new directory: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 37
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 38
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 53
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 73
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 91
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 111
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 131
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 151
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 170
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 183
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 203
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 223
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 233
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 253
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 260
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 268
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 284
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 304
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 324
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 341
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 361
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 376
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 396
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 416
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 436
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 453
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 472
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 487
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 500
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 516
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 536
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 556
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 575
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 595
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 615
#
# -- Scrolling... (1) (2) (3) (4) (5)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 635
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 655
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 672
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 691
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 711
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 730
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 741
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 743
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 763
#
# -- Scrolling... (1)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 779
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 797
#
# -- Scrolling... (1)[v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@67628a0b73672f84f1d4ad5500625d29"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@cb7c1c6857a708743d498c7fa2d913da"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@380ce8e24baabc5fd1e20170da2d1a34"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@c1922deb719f74827e3d6f0315904a64"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@9d758b78edec3f08d3a2201db76d6c95"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@da661e8f9a4154d555cac0b18edc779d"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@6ee655fb9ce4b3a383a1ab9d47d0fedc"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@f472edebc358f54f20b45a98345217b7"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@ff395b95a53af72ca2b492c793d183a8"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@fe4d19283769c352e9e3c942c68d9424"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
#
#
# Your tweets saved to: /home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/data-crawl/node_env/node_env/tweets-data/spx6900.csv
# Total tweets saved: 810
# Got 810 tweets, done scrolling...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"/home/dapek/Documents/TUGAS/PEMROSESAN TEXT/SPX6900-SENTIMENT/tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1973175314974122373  Tue Sep 30 23:57:09 +0000 2025               1
# 1    1973136808931209396  Tue Sep 30 23:54:57 +0000 2025               1
# 2    1973174474062307742  Tue Sep 30 23:53:49 +0000 2025              65
# 3    1973172315874832773  Tue Sep 30 23:45:14 +0000 2025              68
# 4    1973171958922813546  Tue Sep 30 23:43:49 +0000 2025               6
# ..                   ...                             ...             ...
# 811  1972755692198277559  Mon Sep 29 21:16:19 +0000 2025               7
# 812  1972772161828876649  Mon Sep 29 21:15:10 +0000 2025               2
# 813  1972771585724735693  Mon Sep 29 21:12:53 +0000 2025             431
# 814  1972771278294855964  Mon Sep 29 21:11:39 +0000 2025              24
# 815  1972731634756858037  Mon Sep 29 21:11:29 +0000 2025               0
#
#                                              full_text               id_str  \
# 0    Spx6900 the culture of a new generation is the...  1973175314974122373
# 1    @CountryBitcoin @MustStopMurad Spx6900 the cul...  1973174759195288039
# 2    Day 19 of DCA'ing $10 into #SPX6900 every sing...  1973174474062307742
# 3    BREAKING NEWS #SPX6900 has just reached a $1T ...  1973172315874832773
# 4    Hold on tight! Yes it s been a tough frustrati...  1973171958922813546
# ..                                                 ...                  ...
# 811  @CSI444BNB @cz_binance you really need to chec...  1972772451806560425
# 812                     Join the #SPX6900 hype train!   1972772161828876649
# 813  I have nothing to lose and everything to gain ...  1972771585724735693
# 814  The SPX6900 movement will onboard millions of ...  1972771278294855964
# 815           @APompliano You misspelled SPX6900 wrong  1972771237085814875
#
#                                              image_url  \
# 0      https://pbs.twimg.com/media/G2IgfOpW4AAR6oX.jpg
# 1      https://pbs.twimg.com/media/G2If-6gWoAAIjfT.jpg
# 2      https://pbs.twimg.com/media/G2Ifuj9bcAAwRKO.jpg
# 3                                                  NaN
# 4      https://pbs.twimg.com/media/G2IdcIFWcAAAx1W.jpg
# ..                                                 ...
# 811  https://pbs.twimg.com/amplify_video_thumb/1972...
# 812                                                NaN
# 813  https://pbs.twimg.com/amplify_video_thumb/1972...
# 814    https://pbs.twimg.com/media/G2Cv5dPaEAAUNim.jpg
# 815                                                NaN
#
#     in_reply_to_screen_name lang  location  quote_count  reply_count  \
# 0                       NaN   en       NaN            0            1
# 1            CountryBitcoin   en       NaN            0            0
# 2                       NaN   en       NaN            0            2
# 3                       NaN   en       NaN            0            0
# 4                       NaN   en       NaN            0            0
# ..                      ...  ...       ...          ...          ...
# 811               CSI444BNB   en       NaN            2            0
# 812                     NaN   en       NaN            0            0
# 813                     NaN   en       NaN            0           43
# 814                     NaN   en       NaN            2            1
# 815              APompliano   en       NaN            0            1
#
#      retweet_count                                          tweet_url  \
# 0                0  https://x.com/undefined/status/197317531497412...
# 1                0  https://x.com/undefined/status/197317475919528...
# 2                4  https://x.com/undefined/status/197317447406230...
# 3                8  https://x.com/undefined/status/197317231587483...
# 4                0  https://x.com/undefined/status/197317195892281...
# ..             ...                                                ...
# 811              1  https://x.com/undefined/status/197277245180656...
# 812              0  https://x.com/undefined/status/197277216182887...
# 813             85  https://x.com/undefined/status/197277158572473...
# 814              2  https://x.com/undefined/status/197277127829485...
# 815              0  https://x.com/undefined/status/197277123708581...
#
#              user_id_str  username
# 0    1699706276966473728       NaN
# 1    1699706276966473728       NaN
# 2             2834244606       NaN
# 3    1508611559932985349       NaN
# 4    1833947475142385664       NaN
# ..                   ...       ...
# 811  1732718229494116352       NaN
# 812            922337156       NaN
# 813  1858232657017970688       NaN
# 814  1448371881535369217       NaN
# 815  1885528396060307456       NaN
#
# [816 rows x 15 columns]

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah : {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 816.
